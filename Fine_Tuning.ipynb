# %%
doc =open("Resources/Prima_Pars.txt").readlines()

# %%
doc = "".join(doc).split('\n')

# %%
aquinas_dict = {"Article": []}

# %%
for i in range(len(doc)):
    
    if (doc[i].find("ARTICLE")!=-1)&(doc[i].find("[")!=-1):
        
        aquinas_dict["Article"].append(doc[i][doc[i].find("["):])
        
        while (doc[i+1].find("ARTICLE")==-1&(doc[i].find("[")==-1):
               
               i=+1

# %%
import pandas as pd


article = ["ARTICLE", "Obj.", "Sed Contra", "Respondeo", "Reply Obj"]

for a in article:

# %%
a = "dlfksdjfibobsflnisdf"

# %%
a.find("bill")
# Out:
# -1

# %%
article = ["ARTICLE", "Obj.", "Sed Contra", "Respondeo", "Reply Obj"]

# %%
aquinas_dict
# Out:
# {'Article': ['[I, Q. 49, Art. 2]',
#   '[I, Q. 1, Art. 1]',
#   '[I, Q. 1, Art. 2]',
#   '[I, Q. 1, Art. 3]',
#   '[I, Q. 1, Art. 4]',
#   '[I, Q. 1, Art. 5]',
#   '[I, Q. 1, Art. 6]',
#   '[I, Q. 1, Art. 7]',
#   '[I, Q. 1, Art. 8]',
#   '[I, Q. 1, Art. 9]',
#   '[I, Q. 1, Art. 10]',
#   '[I, Q. 2, Art. 1]',
#   '[I, Q. 2, Art. 2]',
#   '[I, Q. 2, Art. 3]',
#   '[I, Q. 3, Art. 1]',
#   '[I, Q. 3, Art. 2]',
#   '[I, Q. 3, Art. 3]',
#   '[I, Q. 3, Art. 4]',
#   '[I, Q. 3, Art. 5]',
#   '[I, Q. 3, Art. 6]',
#   '[I, Q. 3, Art. 7]',
#   '[I, Q. 3, Art. 8]',
#   '[I, Q. 4, Art. 1]',
#   '[I, Q. 4, Art. 2]',
#   '[I, Q. 4, Art. 3]',
#   '[I, Q. 5, Art. 1]',
#   '[I, Q. 5, Art. 2]',
#   '[I, Q. 5, Art. 3]',
#   '[I, Q. 5, Art. 4]',
#   '[I, Q. 5, Art. 5]',
#   '[I, Q. 5, Art. 6]',
#   '[I, Q. 6, Art. 1]',
#   '[I, Q. 6, Art. 2]',
#   '[I. Q. 6, Art. 3]',
#   '[I, Q. 6, Art. 4]',
#   '[I, Q. 7, Art. 1]',
#   '[I, Q. 7, Art. 2]',
#   '[I, Q. 7, Art. 3]',
#   '[I, Q. 7, Art. 4]',
# ...
