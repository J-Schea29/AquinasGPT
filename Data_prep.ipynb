# %%
doc =open("Resources/Prima_Pars.txt").readlines()

# %%
doc = "".join(doc).split('\n')

# %%
def concant_to_space(i, l):
    
    a = 0
    
    st = ""
    
    while (l[a+i]!=''):
        space = " "+ l[i+a]
        st+= space
        
        a+=1

    return(st)

# %%
doc[333]
# Out:
# 'FIRST ARTICLE [I, Q. 1, Art. 1]'

# %%
aquinas_dict = {"Article": [], "Question": [], "Obj. 1": [], "Sed Contra": [], "Respondeo": [], "Reply Obj. 1": []}

for i in range(333, len(doc)):
    
    if (doc[i].find("ARTICLE")!=-1)&(doc[i].find("[")!=-1):
        
        aquinas_dict["Article"].append(doc[i][doc[i].find("["):])
        
        aquinas_dict["Question"].append(doc[i+2])
        
        o_count = 0
        r_count = 0
        
        continu = (doc[i+1].find("ARTICLE")==-1)
        
        while continu:
            
            i+=1
            
            if doc[i].find("Objection 1")!=-1:
                
                o_count +=1
                
                string = concant_to_space(i, doc)
                
                aquinas_dict["Obj. 1"].append(string[string.find(":")+1:].replace("_", ""))
                
                
                
            if (doc[i].find("Obj.")!=-1)&(doc[i].find("Reply Obj")==-1):
                
                o_count +=1
                
                try: 
                    string = concant_to_space(i, doc)
                    
                    aquinas_dict[f"Obj. {o_count}"].append(string[string.find(":")+1:].replace("_", ""))
                    
                except: 
                    
                    string = concant_to_space(i, doc)
                    
                    aquinas_dict[f"Obj. {o_count}"] = [None]*(len(aquinas_dict["Obj. 1"])-1)
                    
                    aquinas_dict[f"Obj. {o_count}"].append(string[string.find(":")+1:].replace("_", ""))
                    
                
            if doc[i].find("_On the contrary,_")!=-1:
                
                aquinas_dict["Sed Contra"].append(concant_to_space(i, doc).replace("_", ""))
                
                
            if doc[i].find("_I answer that,_")!=-1:
                
                aquinas_dict["Respondeo"].append(concant_to_space(i, doc).replace("_", ""))
                
               
            if doc[i].find("Reply Obj")!=-1:
                
                r_count+=1
                
                try:
                    string = concant_to_space(i, doc)
                    aquinas_dict[f"Reply Obj. {r_count}"].append(string[string.find(":")+1:].replace("_", ""))
                    
                except: 
                    string = concant_to_space(i, doc)
                    
                    aquinas_dict[f"Reply Obj. {r_count}"] = [None]*(len(aquinas_dict["Reply Obj. 1"])-1)
                        
                    
                    
                    aquinas_dict[f"Reply Obj. {r_count}"].append(string[string.find(":")+1:].replace("_", ""))
                    
            try:
                if (doc[i+1].find("ARTICLE")==-1):
                    continu = (doc[i+1].find("ARTICLE")==-1)|(doc[i+1].find("[")==-1)
                else:
                    continu = False
            except:
                continu = False
      
        max_length = max(len(lst) for lst in aquinas_dict.values())

        for key, value in aquinas_dict.items():
            if len(value) < max_length:
                aquinas_dict[key].extend([None] * (max_length - len(value)))

# %%
import pandas as pd

aquinas_df = pd.DataFrame(aquinas_dict)

aquinas_df
# Out:
#                  Article                                           Question  \
# 0      [I, Q. 1, Art. 1]  Whether, besides Philosophy, any Further Doctr...
# 1      [I, Q. 1, Art. 2]              Whether Sacred Doctrine Is a Science?
# 2      [I, Q. 1, Art. 3]            Whether Sacred Doctrine Is One Science?
# 3      [I, Q. 1, Art. 4]    Whether Sacred Doctrine Is a Practical Science?
# 4      [I, Q. 1, Art. 5]  Whether Sacred Doctrine Is Nobler than Other S...
# ..                   ...                                                ...
# 579  [I, Q. 118, Art. 1]  Whether the Sensitive Soul Is Transmitted with...
# 580  [I, Q. 118, Art. 2]  Whether the Intellectual Soul Is Produced from...
# 581  [I, Q. 118, Art. 3]  Whether Human Souls Were Created Together at t...
# 582  [I, Q. 119, Art. 1]  Whether Some Part of the Food Is Changed into ...
# 583  [I, Q. 119, Art. 2]   Whether the Semen Is Produced from Surplus Food?
#
#                                                 Obj. 1  \
# 0     It seems that, besides philosophical science,...
# 1     It seems that sacred doctrine is not a scienc...
# 2     It seems that sacred doctrine is not one scie...
# 3     It seems that sacred doctrine is a practical ...
# 4     It seems that sacred doctrine is not nobler t...
# ..                                                 ...
# 579   It would seem that the sensitive soul is not ...
# 580   It would seem that the intellectual soul is p...
# 581   It would seem that human souls were created t...
# 582   It would seem that none of the food is change...
# 583   It would seem that the semen is not produced ...
#
#                                             Sed Contra  \
# 0     On the contrary, It is written (2 Tim. 3:16):...
# 1     On the contrary, Augustine says (De Trin. xiv...
# 2     On the contrary, Holy Scripture speaks of it ...
# 3     On the contrary, Every practical science is c...
# 4     On the contrary, Other sciences are called th...
# ..                                                 ...
# 579   On the contrary, The power in the semen is to...
# 580   On the contrary, It is written in De Eccl. Do...
# 581   On the contrary, It is said (De Eccl. Dogmat....
# 582   On the contrary, Augustine says (De Vera Reli...
# 583   On the contrary, The Philosopher proves in ma...
#
#                                              Respondeo  \
# 0     I answer that, It was necessary for man's sal...
# 1     I answer that, Sacred doctrine is a science. ...
# 2     I answer that, Sacred doctrine is one science...
# 3     I answer that, Sacred doctrine, being one, ex...
# 4     I answer that, Since this science is partly s...
# ..                                                 ...
# 579   I answer that, Some have held that the sensit...
# 580   I answer that, It is impossible for an active...
# 581   I answer that, Some have maintained that it i...
# 582   I answer that, According to the Philosopher (...
# 583   I answer that, This question depends in some ...
#
#                                           Reply Obj. 1  \
# 0     Although those things which are beyond man's ...
# 1     The principles of any science are either in t...
# 2     Sacred doctrine does not treat of God and cre...
# 3                                                 None
# 4     It may well happen that what is in itself the...
# ..                                                 ...
# 579   The sensitive soul is not a perfect self-subs...
# 580   In the passage quoted, the part is put instea...
# 581   God is said to have rested on the seventh day...
# 582   Our Lord does not say that the "whole" of wha...
# 583   Generation is from the substance of the beget...
#
#                                                 Obj. 2  \
# 0     Further, knowledge can be concerned only with...
# 1     Further, no science deals with individual fac...
# 2     Further, in sacred doctrine we treat of angel...
# 3     Further, sacred doctrine is divided into the ...
# 4     Further, it is the sign of a lower science to...
# ..                                                 ...
# 579   Further, in living things the principle of ge...
# 580   Further, as shown above (Q. 76, A. 3), the in...
# 581   Further, spiritual substances before all othe...
# 582   Further, the Philosopher (De Gener. i, 5) dis...
# 583   Further, the son is like his father, in respe...
#
#                                           Reply Obj. 2  \
# 0     Sciences are differentiated according to the ...
# 1     Individual facts are treated of in sacred doc...
# 2     Nothing prevents inferior faculties or habits...
# 3                                                 None
# 4     This science can in a sense depend upon the p...
# ..                                                 ...
# 579   The generating power begets not only by its o...
# 580   Some say that the vital functions observed in...
# 581   Something can be added every day to the perfe...
# 582   By flesh belonging to the species, some have ...
# 583   The likeness of the begetter to the begotten ...
#
#                                                 Obj. 3  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 579   Further, the generator begets its like: so th...
# 580   Further, it is one and the same agent whose a...
# 581   Further, the end of a thing corresponds to it...
# 582   Further, the "radical humor" seems to belong ...
# 583   Further, the food of the generator is sometim...
#
#                                           Reply Obj. 3  ... Obj. 13 Obj. 14  \
# 0                                                 None  ...    None    None
# 1                                                 None  ...    None    None
# 2                                                 None  ...    None    None
# 3                                                 None  ...    None    None
# 4                                                 None  ...    None    None
# ..                                                 ...  ...     ...     ...
# 579   This active force which is in the semen, and ...  ...    None    None
# 580   This argument holds in the case of diverse ag...  ...    None    None
# 581   That the soul remains without the body is due...  ...    None    None
# 582   The "radical humor" is said to comprise whate...  ...    None    None
# 583   These words of Augustine are not to be unders...  ...    None    None
#
#     Obj. 15 Obj. 16 Reply Obj. 11 Reply Obj. 12 Reply Obj. 13 Reply Obj. 14  \
# 0      None    None          None          None          None          None
# 1      None    None          None          None          None          None
# 2      None    None          None          None          None          None
# 3      None    None          None          None          None          None
# 4      None    None          None          None          None          None
# ..      ...     ...           ...           ...           ...           ...
# 579    None    None          None          None          None          None
# 580    None    None          None          None          None          None
# 581    None    None          None          None          None          None
# 582    None    None          None          None          None          None
# 583    None    None          None          None          None          None
#
#     Reply Obj. 15 Reply Obj. 16
# 0            None          None
# 1            None          None
# 2            None          None
# 3            None          None
# 4            None          None
# ..            ...           ...
# 579          None          None
# 580          None          None
# 581          None          None
# 582          None          None
# 583          None          None
#
# [584 rows x 35 columns]

# %%
new_columns = ['Article', 'Question', 'Obj. 1', 'Obj. 2', 'Obj. 3', 'Obj. 4', 'Obj. 5',
               'Obj. 6', 'Obj. 7', 'Obj. 8', 'Obj. 9', 'Obj. 10', 'Obj. 12', 'Obj. 13',
               'Obj. 14', 'Obj. 15', 'Obj. 16', 'Sed Contra', 'Respondeo',
               'Reply Obj. 1', 'Reply Obj. 2', 'Reply Obj. 3', 'Reply Obj. 4',
               'Reply Obj. 5', 'Reply Obj. 6', 'Reply Obj. 7', 'Reply Obj. 8',
               'Reply Obj. 9', 'Reply Obj. 10', 'Reply Obj. 11', 'Reply Obj. 12',
               'Reply Obj. 13', 'Reply Obj. 14', 'Reply Obj. 15', 'Reply Obj. 16']

# Reorder the columns in the dataframe
aquinas_df = aquinas_df[new_columns]

# Reorder the data in the dataframe based on the new column order
aquinas_df = aquinas_df.reindex(columns=new_columns)

# %%
aquinas_df
# Out:
#                  Article                                           Question  \
# 0      [I, Q. 1, Art. 1]  Whether, besides Philosophy, any Further Doctr...
# 1      [I, Q. 1, Art. 2]              Whether Sacred Doctrine Is a Science?
# 2      [I, Q. 1, Art. 3]            Whether Sacred Doctrine Is One Science?
# 3      [I, Q. 1, Art. 4]    Whether Sacred Doctrine Is a Practical Science?
# 4      [I, Q. 1, Art. 5]  Whether Sacred Doctrine Is Nobler than Other S...
# ..                   ...                                                ...
# 579  [I, Q. 118, Art. 1]  Whether the Sensitive Soul Is Transmitted with...
# 580  [I, Q. 118, Art. 2]  Whether the Intellectual Soul Is Produced from...
# 581  [I, Q. 118, Art. 3]  Whether Human Souls Were Created Together at t...
# 582  [I, Q. 119, Art. 1]  Whether Some Part of the Food Is Changed into ...
# 583  [I, Q. 119, Art. 2]   Whether the Semen Is Produced from Surplus Food?
#
#                                                 Obj. 1  \
# 0     It seems that, besides philosophical science,...
# 1     It seems that sacred doctrine is not a scienc...
# 2     It seems that sacred doctrine is not one scie...
# 3     It seems that sacred doctrine is a practical ...
# 4     It seems that sacred doctrine is not nobler t...
# ..                                                 ...
# 579   It would seem that the sensitive soul is not ...
# 580   It would seem that the intellectual soul is p...
# 581   It would seem that human souls were created t...
# 582   It would seem that none of the food is change...
# 583   It would seem that the semen is not produced ...
#
#                                                 Obj. 2  \
# 0     Further, knowledge can be concerned only with...
# 1     Further, no science deals with individual fac...
# 2     Further, in sacred doctrine we treat of angel...
# 3     Further, sacred doctrine is divided into the ...
# 4     Further, it is the sign of a lower science to...
# ..                                                 ...
# 579   Further, in living things the principle of ge...
# 580   Further, as shown above (Q. 76, A. 3), the in...
# 581   Further, spiritual substances before all othe...
# 582   Further, the Philosopher (De Gener. i, 5) dis...
# 583   Further, the son is like his father, in respe...
#
#                                                 Obj. 3  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 579   Further, the generator begets its like: so th...
# 580   Further, it is one and the same agent whose a...
# 581   Further, the end of a thing corresponds to it...
# 582   Further, the "radical humor" seems to belong ...
# 583   Further, the food of the generator is sometim...
#
#                                                 Obj. 4  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 579   Further, if there be in the semen any princip...
# 580   Further, man begets his like in species. But ...
# 581                                               None
# 582   Further, if the food were changed into true h...
# 583   Further, Augustine says (Gen. ad lit. x, 20) ...
#
#                                                 Obj. 5 Obj. 6 Obj. 7 Obj. 8  \
# 0                                                 None   None   None   None
# 1                                                 None   None   None   None
# 2                                                 None   None   None   None
# 3                                                 None   None   None   None
# 4                                                 None   None   None   None
# ..                                                 ...    ...    ...    ...
# 579                                               None   None   None   None
# 580   Further, it cannot be said that God concurs i...   None   None   None
# 581                                               None   None   None   None
# 582   Further, if the food is changed into true hum...   None   None   None
# 583                                               None   None   None   None
#
#      ... Reply Obj. 7 Reply Obj. 8 Reply Obj. 9 Reply Obj. 10 Reply Obj. 11  \
# 0    ...         None         None         None          None          None
# 1    ...         None         None         None          None          None
# 2    ...         None         None         None          None          None
# 3    ...         None         None         None          None          None
# 4    ...         None         None         None          None          None
# ..   ...          ...          ...          ...           ...           ...
# 579  ...         None         None         None          None          None
# 580  ...         None         None         None          None          None
# 581  ...         None         None         None          None          None
# 582  ...         None         None         None          None          None
# 583  ...         None         None         None          None          None
#
#     Reply Obj. 12 Reply Obj. 13 Reply Obj. 14 Reply Obj. 15 Reply Obj. 16
# 0            None          None          None          None          None
# 1            None          None          None          None          None
# 2            None          None          None          None          None
# 3            None          None          None          None          None
# 4            None          None          None          None          None
# ..            ...           ...           ...           ...           ...
# 579          None          None          None          None          None
# 580          None          None          None          None          None
# 581          None          None          None          None          None
# 582          None          None          None          None          None
# 583          None          None          None          None          None
#
# [584 rows x 35 columns]

# %%
aquinas_df.to_csv('Prima_Pars.csv')
